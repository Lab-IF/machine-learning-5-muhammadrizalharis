# %% [markdown]
# # PERTEMUAN 1 **Tanggal:** 14 Maret 202
#
# **Nama:** Muhammad Rizal Haris
# **NIM:** 105841103223
# **Kelas:** 5A Applied Machine Learning
# **Tanggal:** 14 Maret 2026
#
# > Pastikan semua cell sudah dijalankan dan tidak ada error.

# %% [markdown]
# # 1. TUJUAN PRATIKUM
# Praktikum ini bertujuan untuk memahami proses awal dalam analisis data sebelum membangun model machine learning. Pada tahap ini mahasiswa mempelajari bagaimana cara menyiapkan data agar lebih bersih, terstruktur, dan siap dianalisis. Proses yang dilakukan meliputi pemeriksaan struktur dataset, identifikasi nilai yang hilang, penanganan outlier pada beberapa variabel numerik, serta melakukan proses normalisasi atau standardisasi pada data. Selain itu, praktikum ini juga bertujuan untuk melatih kemampuan eksplorasi data menggunakan visualisasi sehingga pola dan hubungan antar variabel dapat dipahami dengan lebih baik sebelum dilakukan tahap pemodelan.

# %% [markdown]
# # 2 Dataset yang Digunakan
#
# Dataset yang digunakan dalam praktikum ini adalah Students Performance in Exams Dataset yang diperoleh dari platform Kaggle. Dataset ini berisi informasi mengenai performa akademik siswa berdasarkan beberapa faktor seperti jenis kelamin, latar belakang pendidikan orang tua, jenis makan siang yang diterima, serta keikutsertaan dalam kursus persiapan ujian.
#
# Sumber dataset:
# https://www.kaggle.com/datasets/spscientist/students-performance-in-exams

# %% [markdown]
# # 3. Langkah Kerja Praktikum
#
# - Menyiapkan lingkungan kerja dengan mengimpor library Python yang dibutuhkan seperti pandas, numpy, seaborn, matplotlib, dan scikit-learn untuk proses analisis dan visualisasi data.
# - Mengunduh dataset Students Performance in Exams dari platform Kaggle kemudian memuat dataset tersebut ke dalam Python menggunakan library pandas.
# - Menampilkan beberapa baris pertama dataset untuk memahami struktur awal data serta mengetahui nama kolom yang tersedia.
# - Memeriksa ukuran dataset untuk mengetahui jumlah baris dan kolom yang terdapat pada data.
# - Mengidentifikasi tipe data pada setiap variabel untuk mengetahui apakah data tersebut termasuk numerik atau kategorikal.
# - Melakukan pengecekan terhadap kemungkinan adanya missing value pada dataset.
# - Melakukan proses pembersihan data jika ditemukan nilai yang hilang atau data yang tidak sesuai.
# - Mengidentifikasi kemungkinan adanya outlier pada variabel numerik menggunakan metode Interquartile Range (IQR).
# - Membatasi nilai ekstrem pada beberapa kolom numerik agar distribusi data menjadi lebih stabil.
# - Melakukan proses scaling pada variabel numerik menggunakan metode StandardScaler untuk menyesuaikan skala antar variabel.
# - Melakukan Exploratory Data Analysis (EDA) dengan membuat beberapa visualisasi data untuk memahami pola distribusi dan hubungan antar variabel.
# - Menganalisis hasil visualisasi yang diperoleh untuk menemukan pola atau informasi penting dari dataset.
# - Menuliskan beberapa insight atau kesimpulan awal berdasarkan hasil eksplorasi data yang telah dilakukan.

# %% [markdown]
# # IMPORT LIBRARY
# - import pandas as pd
# Digunakan untuk memanggil library pandas dengan nama singkat pd. Library ini berfungsi untuk membaca, menampilkan, dan mengolah data dalam bentuk tabel.
# - import numpy as np
# Digunakan untuk memanggil library numpy dengan nama singkat np. Library ini membantu proses perhitungan numerik dan pengolahan array.
# - import matplotlib.pyplot as plt
# Digunakan untuk membuat grafik dasar seperti histogram, diagram batang, dan pengaturan tampilan visualisasi.
# - import seaborn as sns
# Digunakan untuk membuat visualisasi data yang lebih menarik dan lebih mudah dibaca, misalnya boxplot, violin plot, scatter plot, dan heatmap.
# - from sklearn.preprocessing import StandardScaler
# Digunakan untuk mengambil class StandardScaler dari library scikit-learn. Fungsi ini dipakai untuk melakukan standardisasi data numerik agar memiliki skala yang sebanding.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Membaca Dataset
# - Kode pd.read_csv("StudentsPerformance.csv") dipakai untuk membuka dan membaca file dataset yang berformat CSV.
# - Data yang sudah terbaca kemudian disimpan ke dalam variabel df supaya bisa digunakan di langkah berikutnya.
# - Variabel df berisi data dalam bentuk tabel (dataframe) sehingga lebih mudah untuk dilihat dan diolah.
# - Perintah df.head() digunakan untuk menampilkan beberapa baris pertama dari dataset.
# - Tujuannya supaya kita bisa melihat gambaran awal data, seperti isi kolom, contoh nilai, dan struktur datanya.

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Menampilkan Ukuran Dataset
# - Perintah df.shape digunakan untuk melihat ukuran dari dataset yang sedang dipakai.
# - Output yang ditampilkan berupa dua angka yang menunjukkan jumlah baris dan jumlah kolom.
# - Angka pertama merepresentasikan banyaknya data (baris), sedangkan angka kedua menunjukkan jumlah variabel atau fitur (kolom).
# - Dengan melihat hasil ini, kita bisa cepat mengetahui seberapa besar dataset tanpa perlu menghitung secara manual.
# - Informasi ini penting sebagai langkah awal sebelum melakukan analisis lebih lanjut pada data.

# %%
print("Ukuran data:", df.shape)
print("\nTipe data:")
print(df.dtypes)
# Out:
# Ukuran data: (1000, 8)
#
# Tipe data:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Mengecek Missing Value
# - print("Ukuran data:", df.shape) digunakan untuk menampilkan ukuran dataset ke layar.
# - df.shape akan menghasilkan dua nilai, yaitu jumlah baris dan jumlah kolom.
# - Ini membantu kita mengetahui dimensi data secara cepat.
#
# - print("\nTipe data:") berfungsi untuk memberi jeda baris sekaligus judul sebelum menampilkan tipe data.
# - Tujuannya agar output lebih rapi dan mudah dibaca.
#
# - print(df.dtypes) digunakan untuk menampilkan tipe data dari setiap kolom dalam dataset.
# - Dengan ini, kita bisa mengetahui apakah kolom berisi teks (object) atau angka (int64).
# - Informasi ini penting untuk menentukan langkah analisis selanjutnya.
# > Jika semua hasil bernilai 0, berarti dataset tidak memiliki data yang hilang.

# %%
print("\nMissing value:")
print(df.isnull().sum())
# Out:
# Missing value:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Membuat Fungsi Penanganan Outlier
# - def batasi_outlier_iqr(data, kolom) digunakan untuk membuat fungsi dalam menangani nilai outlier pada kolom tertentu.
# - q1 = data[kolom].quantile(0.25) berfungsi untuk mengambil nilai kuartil pertama (25%) sebagai batas bawah awal.
# - q3 = data[kolom].quantile(0.75) digunakan untuk mendapatkan kuartil ketiga (75%) sebagai batas atas awal.
# - iqr = q3 - q1 digunakan untuk menghitung jarak antar kuartil (Interquartile Range).
# - batas_bawah = q1 - 1.5 * iqr digunakan untuk menentukan batas minimum data normal.
# - batas_atas = q3 + 1.5 * iqr digunakan untuk menentukan batas maksimum data normal.
# - data[kolom] = data[kolom].clip(batas_bawah, batas_atas) digunakan untuk membatasi nilai yang berada di luar rentang agar masuk ke batas yang wajar.
# - return data digunakan untuk mengembalikan dataframe yang sudah diperbaiki.
# - Proses pertama diterapkan pada kolom math_score untuk menangani nilai ekstrem pada nilai matematika.
# - Proses kedua diterapkan pada kolom reading_score untuk membersihkan nilai ekstrem pada nilai membaca.
# - Hasil akhirnya disimpan kembali ke dalam df sehingga data yang digunakan sudah lebih bersih dari outlier.
# - Pemilihan dua kolom ini sudah sesuai karena hanya kolom numerik yang bisa diproses dengan metode IQR.

# %%
def batasi_outlier_iqr(data, kolom):
    q1 = data[kolom].quantile(0.25)
    q3 = data[kolom].quantile(0.75)
    iqr = q3 - q1
    batas_bawah = q1 - 1.5 * iqr
    batas_atas = q3 + 1.5 * iqr
    data[kolom] = data[kolom].clip(batas_bawah, batas_atas)
    return data

df = batasi_outlier_iqr(df, "math score")
df = batasi_outlier_iqr(df, "reading score")

# %% [markdown]
# # Melakukan Scaling Data
# - scaler = StandardScaler() digunakan untuk membuat objek yang berfungsi melakukan standardisasi data.
# - kolom_numerik = ["math_score", "reading_score", "writing_score"] digunakan untuk menentukan kolom mana saja yang akan dilakukan proses scaling.
# - scaler.fit_transform(df[kolom_numerik]) digunakan untuk mempelajari distribusi data sekaligus mengubah nilainya ke bentuk standar.
# - Proses ini akan mengubah data sehingga memiliki rata-rata mendekati 0.
# - Selain itu, standar deviasi data akan menjadi mendekati 1.
# - Tujuan scaling adalah agar data memiliki skala yang seragam sehingga lebih optimal saat digunakan dalam model atau analisis.
# - Hasil dari proses ini kemudian disimpan kembali ke dalam kolom numerik yang sama.

# %%
scaler = StandardScaler()
kolom_numerik = ["math score", "reading score", "writing score"]

df[kolom_numerik] = scaler.fit_transform(df[kolom_numerik])
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none    0.391218       0.193085       0.391492
# 1               completed    0.190078       1.434787       1.313269
# 2                    none    1.598061       1.779704       1.642475
# 3                    none   -1.284952      -0.841667      -1.583744
# 4                    none    0.659405       0.606986       0.457333

# %% [markdown]
# # Menampilkan Distribusi Gender
# - df["gender"].value_counts() digunakan untuk menghitung jumlah data pada masing-masing kategori gender.
# - .sort_values() digunakan untuk mengurutkan hasil perhitungan agar tampil lebih terstruktur.
# - plt.figure(figsize=(7,4)) digunakan untuk mengatur ukuran tampilan grafik supaya lebih proporsional.
# - plt.barh(gender_count.index, gender_count.values) digunakan untuk membuat grafik batang horizontal berdasarkan jumlah tiap gender.
# - plt.title(...) digunakan untuk menambahkan judul pada grafik.
# - plt.xlabel(...) digunakan untuk memberi keterangan pada sumbu horizontal.
# - plt.ylabel(...) digunakan untuk memberi keterangan pada sumbu vertikal.
# - plt.show() digunakan untuk menampilkan grafik ke layar.

# %%
gender_count = df["gender"].value_counts().sort_values()

plt.figure(figsize=(7,4))
plt.barh(gender_count.index, gender_count.values)
plt.title("Komposisi Siswa Berdasarkan Gender")
plt.xlabel("Jumlah Siswa")
plt.ylabel("Gender")
plt.show()

# %% [markdown]
# # Menampilkan Histogram Math Score
# - plt.hist(df["math_score"], bins=20, edgecolor="black") digunakan untuk membuat histogram yang menampilkan sebaran nilai matematika.
# - bins=20 digunakan untuk menentukan jumlah pembagian interval pada histogram agar distribusi data terlihat lebih detail.
# - edgecolor="black" berfungsi memberi garis tepi pada setiap batang supaya lebih jelas terlihat.
# - plt.axvline(df["math_score"].mean(), ...) digunakan untuk menambahkan garis vertikal pada nilai rata-rata math score.
# - linestyle="--" digunakan agar garis rata-rata tampil dalam bentuk putus-putus.
# - linewidth=2 digunakan untuk mengatur ketebalan garis agar lebih mudah terlihat.
# - label="Rata-rata" digunakan untuk memberi keterangan pada garis tersebut.
# - plt.legend() digunakan untuk menampilkan keterangan (legend) pada grafik.
# - plt.show() digunakan untuk menampilkan hasil grafik ke layar.

# %%
plt.figure(figsize=(8,5))
plt.hist(df["math score"], bins=20, edgecolor="green")
plt.axvline(df["math score"].mean(), linestyle="--", linewidth=2, label="Rata-rata")
plt.title("Sebaran Nilai Matematika")
plt.xlabel("Math Score")
plt.ylabel("Frekuensi")
plt.legend()
plt.show()

# %% [markdown]
# # Menampilkan Violin Plot
# - sns.violinplot(...) digunakan untuk menampilkan distribusi data numerik dalam bentuk visual yang lebih detail dibandingkan boxplot.
# - x="gender" digunakan untuk menentukan kategori pada sumbu horizontal berdasarkan jenis kelamin.
# - y="writing_score" digunakan untuk menentukan nilai yang dianalisis, yaitu skor menulis.
# - Grafik ini menunjukkan bentuk distribusi data pada masing-masing kategori.
# - Selain itu, grafik juga memperlihatkan sebaran nilai dari setiap kelompok.
# - Kita juga bisa melihat kecenderungan nilai, apakah cenderung tinggi, rendah, atau merata.
# - Visualisasi ini membantu membandingkan pola nilai writing antara siswa laki-laki dan perempuan.

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="gender", y="writing score", data=df)
plt.title("Pola Sebaran Writing Score Berdasarkan Gender")
plt.xlabel("Gender")
plt.ylabel("Writing Score (scaled)")
plt.show()

# %% [markdown]
# # Menampilkan Boxplot
# - sns.boxplot(...) digunakan untuk menampilkan ringkasan distribusi data dalam bentuk boxplot berdasarkan kategori tertentu.
# - Boxplot menampilkan nilai median sebagai garis tengah dalam kotak.
# - Selain itu, boxplot juga menunjukkan kuartil (Q1 dan Q3) yang menggambarkan sebaran data.
# - Rentang data ditunjukkan melalui garis (whisker) yang memperlihatkan batas minimum dan maksimum.
# - Boxplot juga dapat membantu mengidentifikasi adanya kemungkinan outlier.
# - x="lunch" digunakan untuk menentukan kategori pada sumbu horizontal berdasarkan jenis lunch.
# - y="math_score" digunakan untuk menentukan nilai yang dianalisis, yaitu skor matematika.
# - plt.xticks(rotation=10) digunakan untuk memutar label pada sumbu x agar lebih mudah dibaca.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="lunch", y="math score", data=df)
plt.title("Perbandingan Math Score Berdasarkan Jenis Lunch")
plt.xlabel("Jenis Lunch")
plt.ylabel("Math Score (scaled)")
plt.xticks(rotation=10)
plt.show()

# %% [markdown]
# # Menampilkan Scatter Plot
# - sns.scatterplot(...) digunakan untuk menampilkan hubungan antara dua variabel numerik dalam bentuk titik-titik.
# - x="reading_score" digunakan untuk menentukan nilai pada sumbu horizontal, yaitu skor membaca.
# - y="writing_score" digunakan untuk menentukan nilai pada sumbu vertikal, yaitu skor menulis.
# - hue="gender" digunakan untuk membedakan warna titik berdasarkan kategori gender.
# - Dengan adanya perbedaan warna, pola tiap kelompok menjadi lebih mudah diamati.
# - Grafik ini membantu melihat apakah ada hubungan antara nilai membaca dan menulis.
# - Selain itu, dapat terlihat apakah siswa dengan nilai membaca tinggi cenderung memiliki nilai menulis yang tinggi juga.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="reading score", y="writing score", hue="gender", data=df)
plt.title("Hubungan Reading Score dan Writing Score")
plt.xlabel("Reading Score (scaled)")
plt.ylabel("Writing Score (scaled)")
plt.show()

# %% [markdown]
# # Menampilkan Heatmap Korelasi
# - df[kolom_numerik].corr() digunakan untuk menghitung hubungan (korelasi) antar kolom numerik.
# - sns.heatmap(...) digunakan untuk menampilkan hasil korelasi dalam bentuk visual peta warna.
# - annot=True digunakan untuk menampilkan nilai korelasi langsung di dalam setiap kotak.
# - cmap="coolwarm" digunakan untuk memberikan gradasi warna dari rendah ke tinggi agar lebih mudah dibedakan.
# - fmt=".2f" digunakan untuk membatasi tampilan angka korelasi menjadi dua digit di belakang koma.
# - Grafik ini membantu melihat seberapa kuat hubungan antar variabel numerik.
# - Dari sini dapat diamati hubungan antara math score, reading score, dan writing score.

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[kolom_numerik].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelasi Antar Skor Akademik")
plt.show()

# %% [markdown]
# # Menampilkan Rata-rata Nilai Berdasarkan Pendidikan Orang Tua
# - df.groupby("parent_education")["math_score"].mean() digunakan untuk mengelompokkan data berdasarkan pendidikan orang tua, lalu menghitung rata-rata nilai matematika pada tiap kelompok.
# - .sort_values() digunakan untuk mengurutkan hasil rata-rata agar lebih mudah dibandingkan dari yang kecil ke besar.
# - plt.barh(...) digunakan untuk menampilkan hasil tersebut dalam bentuk diagram batang horizontal.
# - Visualisasi ini membantu melihat perbedaan rata-rata nilai matematika siswa berdasarkan latar belakang pendidikan orang tua.
# - Dari grafik, kita bisa membandingkan kelompok mana yang memiliki rata-rata nilai lebih tinggi atau lebih rendah.

# %%
rata_math = df.groupby("parental level of education")["math score"].mean().sort_values()

plt.figure(figsize=(9,5))
plt.barh(rata_math.index, rata_math.values)
plt.title("Rata-rata Math Score Berdasarkan Pendidikan Orang Tua")
plt.xlabel("Rata-rata Math Score (scaled)")
plt.ylabel("Pendidikan Orang Tua")
plt.show()

# %% [markdown]
# #  Bagian visualisasi data digunakan untuk memahami pola serta hubungan antar variabel dalam dataset.
# - Pada praktikum ini dibuat beberapa grafik untuk menggambarkan distribusi data, perbandingan antar kategori, dan hubungan antar variabel numerik.
# - Visualisasi yang digunakan meliputi:
#   1. Grafik distribusi jumlah siswa berdasarkan gender.
#   2. Histogram untuk melihat pola sebaran nilai matematika.
#   3. Violin plot untuk membandingkan distribusi nilai writing berdasarkan gender.
#   4. Boxplot untuk melihat perbedaan nilai matematika berdasarkan jenis lunch.
#   5. Scatter plot untuk menganalisis hubungan antara reading score dan writing score.
#   6. Heatmap untuk melihat tingkat korelasi antar nilai akademik.
#   7. Diagram batang untuk membandingkan rata-rata nilai matematika berdasarkan pendidikan orang tua.
#
# #  Insight yang diperoleh dari visualisasi:
#   1. Jumlah siswa laki-laki dan perempuan terlihat tidak jauh berbeda sehingga distribusinya cukup seimbang.
#   2. Nilai matematika sebagian besar berada di rentang tengah, hanya sedikit yang berada di nilai sangat rendah atau sangat tinggi.
#   3. Terdapat perbedaan pola penyebaran nilai writing antara siswa laki-laki dan perempuan.
#   4. Hasil boxplot menunjukkan adanya variasi performa matematika pada siswa berdasarkan jenis lunch yang dikonsumsi.
#   5. Scatter plot menunjukkan adanya hubungan positif antara nilai reading dan writing, dimana peningkatan salah satu cenderung diikuti oleh yang lain.
#   6. Heatmap memperlihatkan bahwa ketiga skor akademik memiliki hubungan yang cukup kuat satu sama lain.
#   7. Rata-rata nilai matematika juga berbeda pada tiap kelompok pendidikan orang tua, yang menunjukkan adanya pengaruh latar belakang terhadap performa siswa.
